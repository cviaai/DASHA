# %%
import gym
from gym import error
from gym.utils import closer
from PIL import Image
import torch
from pypylon import pylon
import numpy as np
import cv2
from ctypes import *
import glob
import matplotlib.pylab as pl
import matplotlib.pyplot as plt
import gym
from gym import error
from gym.utils import closer
from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common import make_vec_env
from stable_baselines import A2C, PPO2
from gym import spaces
from pypylon import pylon
import stable_baselines
import time
from matplotlib import cm
from stable_baselines.common.schedules import LinearSchedule
# %matplotlib inline

env_closer = closer.Closer()
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
class CorningEnv(object):
    """The main OpenAI Gym class. It encapsulates an environment with
    arbitrary behind-the-scenes dynamics. An environment can be
    partially or fully observed.
    The main API methods that users of this class need to know are:
        step
        reset
        render
        close
        seed
    And set the following attributes:
        action_space: The Space object corresponding to valid actions
        observation_space: The Space object corresponding to valid observations
        reward_range: A tuple corresponding to the min and max possible rewards
    Note: a default reward range set to [-inf,+inf] already exists. Set it if you want a narrower range.
    The methods are accessed publicly as "step", "reset", etc...
    
    """
    metadata = {'render.modes': ['rgb_array']}
    

    
    def __init__(self, camera, 
                     GainRaw = 36, 
                     ExposureTimeRaw = 20000, 
                     AcquisitionFrameRateAbs = 10,
                     Width = 417,
                     Height = 404,
                     threshold = 85):
        
        ##############camera##############
        
        # Create an instant camera object with the camera device found first.
        #self.camera = pylon.InstantCamera(pylon.TlFactory.GetInstance().CreateFirstDevice())
        #self.camera.Open()
        
        self.camera = camera
        
        # https://docs.baslerweb.com/features
        self.camera.GainRaw.Value = GainRaw
        self.camera.ExposureTimeRaw.Value = ExposureTimeRaw
        self.camera.AcquisitionFrameRateAbs.Value = AcquisitionFrameRateAbs
        
        # get width and height from camera for making obs space
        self.camera.Width.Value = Width
        self.camera.Height.Value = Height
        print(self.camera.Width.GetValue(), self.camera.Height.GetValue())
        
        
        ##############lens###############
        # corning lib
        self.lib = cdll.LoadLibrary(r"C:\Users\CIG\Documents\MATLAB\ComCasp64.dll")
        #Check if Maxim driver dll is loaded
        eCOMCaspErr = getattr(self.lib,'Casp_OpenCOM')
        print('eCOMCaspErr:', eCOMCaspErr(), self.lib.Casp_OpenCOM())
        
        
        ##############env action and observation##############
        # Focus Voltage
        self.action_space = spaces.Discrete(69)
        # image
        self.observation_space = spaces.Box(low=0, high=255, 
                                             shape=(Height, Width, 3),dtype = np.uint8)
        
        
        ##############for grabbing images from camera##############
        # code from https://github.com/basler/pypylon/blob/master/samples/opencv.py
        img = pylon.PylonImage()
        self.converter = pylon.ImageFormatConverter()
        
        # converting to opencv bgr format
        self.converter.OutputPixelFormat = pylon.PixelType_BGR8packed
        self.converter.OutputBitAlignment = pylon.OutputBitAlignment_MsbAligned
        
        ##############YOLO##############
        self.model_yolo = torch.hub.load('ultralytics/yolov5', 'yolov5s', 
                                         force_reload=True, 
                                         pretrained=True)
        
        ########################################################
        self.threshold = threshold
        self.file_path = r'C:\Users\CIG\Documents\imgs_RL'
        self.i = 0
        time.sleep(1)
        
#     def compute_reward(self, achieved_goal, desired_goal, info):
#         """Compute the step reward. This externalizes the reward function and makes
#         it dependent on a desired goal and the one that was achieved. If you wish to include
#         additional rewards that are independent of the goal, you can include the necessary values
#         to derive it in 'info' and compute it accordingly.
#         Args:
#             achieved_goal (object): the goal that was achieved during execution
#             desired_goal (object): the desired goal that we asked the agent to attempt to achieve
#             info (dict): an info dictionary with additional information
#         Returns:
#             float: The reward that corresponds to the provided achieved goal w.r.t. to the desired
#             goal. Note that the following should always hold true:
#                 ob, reward, done, info = env.step()
#                 assert reward == env.compute_reward(ob['achieved_goal'], ob['goal'], info)
#         """
#         raise NotImplementedError
        
        
    def find_class(self, results, obj = 'car'):
        len_of_class = len(results.pred)
        pred_class = [int(results.pred[0][i].numpy()[5]) for i in range(len(results.pred[0]))]
        #list_of_yolo_classes = list(zip(results.names, range(0, len(results.names))))
        pred_names = [results.names[i] for i in pred_class]
        if obj in pred_names:
            index = pred_names.index(obj)
            return results.pred[0][index].numpy()
        else:
            return np.array([])
        
    def focus_value(self, im):
        # Calculate the gradient
        sobelx = cv2.Sobel(np.float32(im), cv2.CV_64F ,1 , 0, ksize=5)
        sobely = cv2.Sobel(np.float32(im),cv2.CV_64F,0,1,ksize=5)

        abs_sobel_x = cv2.convertScaleAbs(sobelx) # converting back to uint8
        abs_sobel_y = cv2.convertScaleAbs(sobely)
        #print(abs_sobel_x )

        # Combine the two gradients with equal weight
        dst = cv2.addWeighted(abs_sobel_x,0.5,abs_sobel_y,0.5,0)
        #print(dst)

        # Calculate the average gradient for the image
        # I convert it to a numpy array for ease of calculation
        return pl.asarray(dst).mean()
    
    def lens_movement(self, action):
        x = c_double(action)
        self.lib.Casp_SetFocusVoltage(x)
        time.sleep(2)
        
    def grab_image(self):
        #https://github.com/basler/pypylon/blob/master/samples/opencv.py
        self.camera.StartGrabbing()
        while 1:
            grabResult = self.camera.RetrieveResult(5000, pylon.TimeoutHandling_ThrowException)
            if grabResult.GrabSucceeded():
                # Access the image data
                image = self.converter.Convert(grabResult)
                image = image.GetArray()
#                 print(img[0])
#                 print('shape:', img.shape)
#                 plt.imshow(img)
                break
        self.camera.StopGrabbing()
        return image
    
    def step(self, action):
        
        print('real action:', action)
        if action < 24:
            action = 24
            
        self.lens_movement(action)
        
        
        camera_observation = self.grab_image()
        prediction_yolo = self.model_yolo(camera_observation)
        final_result_yolo = self.find_class(prediction_yolo)
        
        if final_result_yolo.size == 0:
            print('not detected')
            foc_value = -1
            betta = 0.5
            reward = -100-betta*self.i
            #reward = -100
            
        else:
            image = Image.fromarray(camera_observation)
            image = image.crop((final_result_yolo[0], 
                             final_result_yolo[1], 
                             final_result_yolo[2], 
                             final_result_yolo[3]))
            foc_value = self.focus_value(image)
            
        if foc_value > self.threshold: #or self.i == 20:
            done = True
            reward = 1
            print('------',True, action, self.i, '------')
        else:
            done = False
            reward = 1 - 0.001*(foc_value - self.threshold)**2
            #reward = -1
            print(False, action)
            
        im = Image.fromarray(camera_observation)
        filename = self.file_path + "\saved_pypylon_img_%s.png" % (str(action))
        im.save(filename)
        
        self.i+=1
        #print(camera_observation)
        camera_observation = camera_observation.astype(np.uint8)
            
        return camera_observation, reward, done, {}
  

    def reset(self):
        """Resets the environment to an initial state and returns an initial
        observation.
        Note that this function should not reset the environment's random
        number generator(s); random variables in the environment's state should
        be sampled independently between multiple calls to `reset()`. In other
        words, each call of `reset()` should yield an environment suitable for
        a new episode, independent of previous episodes.
        Returns:
            observation (object): the initial observation.
        """
        x = c_double(24)
        self.lib.Casp_SetFocusVoltage(x)
        self.i = 0
        time.sleep(1)
        return self.grab_image()


    def close(self):
        """Override close in your subclass to perform any necessary cleanup.
        Environments will automatically close() themselves when
        garbage collected or when the program exits.
        """
        pass

# %%
# Create an instant camera object with the camera device found first.
camera = pylon.InstantCamera(pylon.TlFactory.GetInstance().CreateFirstDevice())
camera.Open()

# %%
env = CorningEnv(camera)
# Out:
# 417 404
# eCOMCaspErr: 0 0
# Downloading: "https://github.com/ultralytics/yolov5/archive/master.zip" to C:\Users\CIG/.cache\torch\hub\master.zip
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Focus                     [3, 32, 3]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1    156928  models.common.C3                        [128, 128, 3]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  1    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1    656896  models.common.SPP                       [512, 512, [5, 9, 13]]
#   9                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1    229245  models.yolo.Detect                      [80, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model Summary: 283 layers, 7276605 parameters, 7276605 gradients, 17.1 GFLOPS
# Adding autoShape...

# %%
# TIMESTEPS = 1000
# sched_LR = LinearSchedule(TIMESTEPS, 0.0005, 0.000001)

model = PPO2(MlpPolicy, env, 
             #learning_rate = sched_LR.value,
             verbose=1, 
             tensorboard_log = '')
# Out:
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=1000, tb_log_name="reward_2", reset_num_timesteps=False)
# Out:
# real action: 3
# False 24
# real action: 25
# False 25
# real action: 30
# False 30
# real action: 49
# ------ True 49 6 ------
# real action: 3
# False 24
# real action: 53
# False 53
# real action: 49
# ------ True 49 2 ------
# real action: 27
# False 27
# real action: 11
# False 24
# real action: 41
# False 41
# real action: 48
# ------ True 48 3 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 43
# False 43
# real action: 57
# False 57
# real action: 17
# False 24
# real action: 49
# ------ True 49 3 ------
# real action: 58
# False 58
# real action: 49
# ------ True 49 1 ------
# real action: 18
# False 24
# real action: 45
# False 45
# real action: 49
# ------ True 49 2 ------
# real action: 49
# ------ True 49 0 ------
# real action: 50
# ------ True 50 0 ------
# real action: 55
# False 55
# real action: 48
# ------ True 48 1 ------
# real action: 50
# ------ True 50 0 ------
# real action: 58
# False 58
# real action: 6
# False 24
# real action: 28
# False 28
# real action: 42
# False 42
# real action: 49
# ------ True 49 4 ------
# real action: 19
# False 24
# real action: 63
# False 63
# real action: 27
# False 27
# real action: 6
# False 24
# real action: 54
# False 54
# real action: 49
# ------ True 49 5 ------
# real action: 6
# False 24
# real action: 23
# False 24
# real action: 49
# ------ True 49 2 ------
# real action: 27
# False 27
# real action: 21
# False 24
# real action: 49
# ------ True 49 2 ------
# real action: 47
# False 47
# real action: 39
# False 39
# real action: 21
# False 24
# real action: 3
# False 24
# real action: 31
# False 31
# real action: 1
# False 24
# real action: 57
# False 57
# real action: 4
# False 24
# real action: 48
# ------ True 48 8 ------
# real action: 28
# False 28
# real action: 50
# ------ True 50 1 ------
# real action: 26
# False 26
# real action: 62
# False 62
# real action: 40
# False 40
# real action: 48
# ------ True 48 3 ------
# real action: 48
# ------ True 48 0 ------
# real action: 4
# False 24
# real action: 13
# False 24
# real action: 60
# False 60
# real action: 68
# False 68
# real action: 0
# False 24
# real action: 31
# False 31
# real action: 36
# False 36
# real action: 61
# False 61
# real action: 40
# False 40
# real action: 49
# ------ True 49 9 ------
# real action: 19
# False 24
# real action: 27
# False 27
# real action: 36
# False 36
# real action: 13
# False 24
# real action: 26
# False 26
# real action: 2
# False 24
# real action: 9
# False 24
# real action: 45
# False 45
# real action: 65
# False 65
# real action: 67
# False 67
# real action: 55
# False 55
# real action: 49
# ------ True 49 11 ------
# real action: 25
# False 25
# real action: 35
# False 35
# real action: 55
# False 55
# real action: 19
# False 24
# real action: 21
# False 24
# real action: 27
# False 27
# real action: 49
# ------ True 49 6 ------
# real action: 60
# False 60
# real action: 2
# False 24
# real action: 48
# ------ True 48 2 ------
# real action: 43
# False 43
# real action: 49
# ------ True 49 1 ------
# real action: 26
# False 26
# real action: 34
# False 34
# real action: 9
# False 24
# real action: 49
# ------ True 49 3 ------
# real action: 25
# False 25
# real action: 34
# False 34
# real action: 45
# False 45
# real action: 48
# ------ True 48 3 ------
# real action: 50
# ------ True 50 0 ------
# real action: 6
# False 24
# real action: 48
# ------ True 48 1 ------
# real action: 58
# False 58
# real action: 2
# False 24
# real action: 48
# ------ True 48 2 ------
# real action: 62
# False 62
# real action: 60
# False 60
# real action: 6
# False 24
# real action: 49
# ------ True 49 3 ------
# real action: 61
# False 61
# real action: 29
# False 29
# real action: 7
# False 24
# real action: 9
# False 24
# real action: 60
# False 60
# real action: 55
# False 55
# real action: 59
# False 59
# real action: 24
# False 24
# real action: 49
# ------ True 49 8 ------
# real action: 49
# ------ True 49 0 ------
# real action: 3
# False 24
# real action: 27
# False 27
# real action: 34
# False 34
# real action: 65
# False 65
# real action: 17
# False 24
# real action: 51
# False 51
# -------------------------------------
# | approxkl           | 0.0006173066 |
# | clipfrac           | 0.0          |
# | explained_variance | 0            |
# | fps                | 0            |
# | n_updates          | 1            |
# | policy_entropy     | 3.720353     |
# | policy_loss        | -0.018701708 |
# | serial_timesteps   | 128          |
# | time_elapsed       | 0            |
# | total_timesteps    | 2816         |
# | value_loss         | 126.000824   |
# -------------------------------------
# real action: 10
# False 24
# real action: 12
# False 24
# real action: 49
# ------ True 49 8 ------
# real action: 27
# False 27
# real action: 49
# ------ True 49 1 ------
# real action: 49
# ------ True 49 0 ------
# real action: 14
# False 24
# real action: 37
# False 37
# real action: 32
# False 32
# real action: 25
# False 25
# real action: 65
# False 65
# real action: 7
# False 24
# real action: 48
# ------ True 48 6 ------
# real action: 49
# ------ True 49 0 ------
# real action: 67
# False 67
# real action: 49
# ------ True 49 1 ------
# real action: 43
# False 43
# real action: 18
# False 24
# real action: 65
# False 65
# real action: 53
# False 53
# real action: 20
# False 24
# real action: 48
# ------ True 48 5 ------
# real action: 5
# False 24
# real action: 49
# ------ True 49 1 ------
# real action: 9
# False 24
# real action: 48
# ------ True 48 1 ------
# real action: 64
# False 64
# real action: 48
# ------ True 48 1 ------
# real action: 47
# False 47
# real action: 48
# ------ True 48 1 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 61
# False 61
# real action: 22
# False 24
# real action: 28
# False 28
# real action: 61
# False 61
# real action: 56
# False 56
# real action: 6
# False 24
# real action: 10
# False 24
# real action: 48
# ------ True 48 7 ------
# real action: 49
# ------ True 49 0 ------
# real action: 55
# False 55
# real action: 49
# ------ True 49 1 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 2
# False 24
# real action: 9
# False 24
# real action: 49
# ------ True 49 2 ------
# real action: 48
# ------ True 48 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 34
# False 34
# real action: 18
# False 24
# real action: 49
# ------ True 49 2 ------
# real action: 49
# ------ True 49 0 ------
# real action: 68
# False 68
# real action: 49
# ------ True 49 1 ------
# real action: 51
# False 51
# real action: 49
# ------ True 49 1 ------
# real action: 18
# False 24
# real action: 54
# False 54
# real action: 49
# ------ True 49 2 ------
# real action: 49
# ------ True 49 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 28
# False 28
# real action: 22
# False 24
# real action: 48
# ------ True 48 2 ------
# real action: 56
# False 56
# real action: 45
# False 45
# real action: 48
# ------ True 48 2 ------
# real action: 50
# ------ True 50 0 ------
# real action: 27
# False 27
# real action: 34
# False 34
# real action: 48
# ------ True 48 2 ------
# real action: 48
# ------ True 48 0 ------
# real action: 25
# False 25
# real action: 26
# False 26
# real action: 30
# False 30
# real action: 65
# False 65
# real action: 48
# ------ True 48 4 ------
# real action: 1
# False 24
# real action: 53
# False 53
# real action: 26
# False 26
# real action: 28
# False 28
# real action: 45
# False 45
# real action: 15
# False 24
# real action: 29
# False 29
# real action: 18
# False 24
# real action: 5
# False 24
# real action: 64
# False 64
# real action: 66
# False 66
# real action: 49
# ------ True 49 11 ------
# real action: 57
# False 57
# real action: 48
# ------ True 48 1 ------
# real action: 10
# False 24
# real action: 37
# False 37
# real action: 48
# ------ True 48 2 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 5
# False 24
# real action: 34
# False 34
# real action: 49
# ------ True 49 2 ------
# real action: 5
# False 24
# real action: 40
# False 40
# real action: 67
# False 67
# real action: 38
# False 38
# real action: 15
# False 24
# real action: 49
# ------ True 49 5 ------
# real action: 38
# False 38
# real action: 48
# ------ True 48 1 ------
# real action: 21
# False 24
# real action: 23
# False 24
# real action: 7
# False 24
# real action: 44
# False 44
# real action: 31
# False 31
# real action: 10
# False 24
# real action: 33
# False 33
# real action: 27
# False 27
# real action: 48
# ------ True 48 8 ------
# real action: 40
# False 40
# real action: 65
# False 65
# real action: 57
# False 57
# real action: 45
# False 45
# real action: 32
# False 32
# real action: 67
# False 67
# real action: 1
# False 24
# real action: 58
# False 58
# -------------------------------------
# | approxkl           | 0.0013688453 |
# | clipfrac           | 0.0          |
# | explained_variance | 0            |
# | fps                | 0            |
# | n_updates          | 2            |
# | policy_entropy     | 3.6203015    |
# | policy_loss        | -0.030326255 |
# | serial_timesteps   | 256          |
# | time_elapsed       | 331          |
# | total_timesteps    | 2944         |
# | value_loss         | 114.6935     |
# -------------------------------------
# real action: 49
# ------ True 49 8 ------
# real action: 27
# False 27
# real action: 51
# False 51
# real action: 20
# False 24
# real action: 48
# ------ True 48 3 ------
# real action: 50
# ------ True 50 0 ------
# real action: 59
# False 59
# real action: 13
# False 24
# real action: 48
# ------ True 48 2 ------
# real action: 23
# False 24
# real action: 8
# False 24
# real action: 8
# False 24
# real action: 33
# False 33
# real action: 49
# ------ True 49 4 ------
# real action: 34
# False 34
# real action: 55
# False 55
# real action: 49
# ------ True 49 2 ------
# real action: 39
# False 39
# real action: 50
# ------ True 50 1 ------
# real action: 34
# False 34
# real action: 48
# ------ True 48 1 ------
# real action: 57
# False 57
# real action: 33
# False 33
# real action: 49
# ------ True 49 2 ------
# real action: 63
# False 63
# real action: 32
# False 32
# real action: 10
# False 24
# real action: 10
# False 24
# real action: 49
# ------ True 49 4 ------
# real action: 48
# ------ True 48 0 ------
# real action: 28
# False 28
# real action: 47
# False 47
# real action: 39
# False 39
# real action: 62
# False 62
# real action: 15
# False 24
# real action: 58
# False 58
# real action: 48
# ------ True 48 6 ------
# real action: 58
# False 58
# real action: 5
# False 24
# real action: 6
# False 24
# real action: 49
# ------ True 49 3 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 54
# False 54
# real action: 49
# ------ True 49 1 ------
# real action: 43
# False 43
# real action: 32
# False 32
# real action: 48
# ------ True 48 2 ------
# real action: 48
# ------ True 48 0 ------
# real action: 28
# False 28
# real action: 18
# False 24
# real action: 48
# ------ True 48 2 ------
# real action: 15
# False 24
# real action: 39
# False 39
# real action: 6
# False 24
# real action: 50
# ------ True 50 3 ------
# real action: 4
# False 24
# real action: 49
# ------ True 49 1 ------
# real action: 27
# False 27
# real action: 5
# False 24
# real action: 37
# False 37
# real action: 16
# False 24
# real action: 16
# False 24
# real action: 38
# False 38
# real action: 55
# False 55
# real action: 40
# False 40
# real action: 4
# False 24
# real action: 49
# ------ True 49 9 ------
# real action: 24
# False 24
# real action: 48
# ------ True 48 1 ------
# real action: 37
# False 37
# real action: 59
# False 59
# real action: 49
# ------ True 49 2 ------
# real action: 48
# ------ True 48 0 ------
# real action: 13
# False 24
# real action: 56
# False 56
# real action: 48
# ------ True 48 2 ------
# real action: 53
# False 53
# real action: 38
# False 38
# real action: 45
# False 45
# real action: 50
# ------ True 50 3 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 6
# False 24
# real action: 12
# False 24
# real action: 48
# ------ True 48 2 ------
# real action: 48
# ------ True 48 0 ------
# real action: 5
# False 24
# real action: 49
# ------ True 49 1 ------
# real action: 41
# False 41
# real action: 50
# ------ True 50 1 ------
# real action: 1
# False 24
# real action: 55
# False 55
# real action: 48
# ------ True 48 2 ------
# real action: 27
# False 27
# real action: 65
# False 65
# real action: 49
# ------ True 49 2 ------
# real action: 8
# False 24
# real action: 23
# False 24
# real action: 49
# ------ True 49 2 ------
# real action: 60
# False 60
# real action: 60
# False 60
# real action: 0
# False 24
# real action: 55
# False 55
# real action: 27
# False 27
# real action: 45
# False 45
# real action: 41
# False 41
# real action: 42
# False 42
# real action: 48
# ------ True 48 8 ------
# real action: 2
# False 24
# real action: 53
# False 53
# real action: 28
# False 28
# real action: 50
# ------ True 50 3 ------
# real action: 49
# ------ True 49 0 ------
# real action: 13
# False 24
# real action: 40
# False 40
# real action: 22
# False 24
# real action: 22
# False 24
# real action: 53
# False 53
# real action: 1
# False 24
# real action: 44
# False 44
# real action: 49
# ------ True 49 7 ------
# real action: 56
# False 56
# real action: 48
# ------ True 48 1 ------
# real action: 56
# False 56
# real action: 48
# ------ True 48 1 ------
# -------------------------------------
# | approxkl           | 0.004329059  |
# | clipfrac           | 0.017578125  |
# | explained_variance | 0            |
# | fps                | 0            |
# | n_updates          | 3            |
# | policy_entropy     | 3.4298904    |
# | policy_loss        | -0.052197322 |
# | serial_timesteps   | 384          |
# | time_elapsed       | 674          |
# | total_timesteps    | 3072         |
# | value_loss         | 72.22497     |
# -------------------------------------
# real action: 63
# False 63
# real action: 55
# False 55
# real action: 49
# ------ True 49 2 ------
# real action: 48
# ------ True 48 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 58
# False 58
# real action: 28
# False 28
# real action: 67
# False 67
# real action: 63
# False 63
# real action: 48
# ------ True 48 4 ------
# real action: 39
# False 39
# real action: 49
# ------ True 49 1 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 47
# False 47
# real action: 45
# False 45
# real action: 49
# ------ True 49 2 ------
# real action: 31
# False 31
# real action: 48
# ------ True 48 1 ------
# real action: 51
# False 51
# real action: 49
# ------ True 49 1 ------
# real action: 2
# False 24
# real action: 49
# ------ True 49 1 ------
# real action: 9
# False 24
# real action: 62
# False 62
# real action: 51
# False 51
# real action: 3
# False 24
# real action: 9
# False 24
# real action: 48
# ------ True 48 5 ------
# real action: 30
# False 30
# real action: 10
# False 24
# real action: 34
# False 34
# real action: 48
# ------ True 48 3 ------
# real action: 27
# False 27
# real action: 48
# ------ True 48 1 ------
# real action: 11
# False 24
# real action: 28
# False 28
# real action: 11
# False 24
# real action: 49
# ------ True 49 3 ------
# real action: 28
# False 28
# real action: 46
# False 46
# real action: 49
# ------ True 49 2 ------
# real action: 10
# False 24
# real action: 49
# ------ True 49 1 ------
# real action: 66
# False 66
# real action: 48
# ------ True 48 1 ------
# real action: 49
# ------ True 49 0 ------
# real action: 16
# False 24
# real action: 48
# ------ True 48 1 ------
# real action: 49
# ------ True 49 0 ------
# real action: 30
# False 30
# real action: 48
# ------ True 48 1 ------
# real action: 6
# False 24
# real action: 49
# ------ True 49 1 ------
# real action: 40
# False 40
# real action: 49
# ------ True 49 1 ------
# real action: 64
# False 64
# real action: 49
# ------ True 49 1 ------
# real action: 48
# ------ True 48 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 5
# False 24
# real action: 33
# False 33
# real action: 67
# False 67
# real action: 48
# ------ True 48 3 ------
# real action: 49
# ------ True 49 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 65
# False 65
# real action: 48
# ------ True 48 1 ------
# real action: 48
# ------ True 48 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 10
# False 24
# real action: 31
# False 31
# real action: 49
# ------ True 49 2 ------
# real action: 21
# False 24
# real action: 32
# False 32
# real action: 14
# False 24
# real action: 42
# False 42
# real action: 48
# ------ True 48 4 ------
# real action: 48
# ------ True 48 0 ------
# real action: 24
# False 24
# real action: 49
# ------ True 49 1 ------
# real action: 33
# False 33
# real action: 49
# ------ True 49 1 ------
# real action: 49
# ------ True 49 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 14
# False 24
# real action: 59
# False 59
# real action: 48
# ------ True 48 2 ------
# real action: 48
# ------ True 48 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 55
# False 55
# real action: 45
# False 45
# real action: 31
# False 31
# real action: 49
# ------ True 49 3 ------
# real action: 53
# False 53
# real action: 45
# False 45
# real action: 10
# False 24
# real action: 49
# ------ True 49 3 ------
# real action: 25
# False 25
# real action: 49
# ------ True 49 1 ------
# real action: 49
# ------ True 49 0 ------
# real action: 42
# False 42
# real action: 32
# False 32
# real action: 49
# ------ True 49 2 ------
# real action: 48
# ------ True 48 0 ------
# real action: 22
# False 24
# real action: 3
# False 24
# real action: 68
# False 68
# real action: 49
# ------ True 49 3 ------
# real action: 25
# False 25
# real action: 49
# ------ True 49 1 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 16
# False 24
# real action: 46
# False 46
# real action: 58
# False 58
# real action: 14
# False 24
# real action: 21
# False 24
# real action: 49
# ------ True 49 5 ------
# real action: 48
# ------ True 48 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 39
# False 39
# ------------------------------------
# | approxkl           | 0.005393591 |
# | clipfrac           | 0.0         |
# | explained_variance | 0           |
# | fps                | 0           |
# | n_updates          | 4           |
# | policy_entropy     | 3.1350558   |
# | policy_loss        | -0.07187484 |
# | serial_timesteps   | 512         |
# | time_elapsed       | 1.02e+03    |
# | total_timesteps    | 3200        |
# | value_loss         | 33.710697   |
# ------------------------------------
# real action: 49
# ------ True 49 1 ------
# real action: 62
# False 62
# real action: 48
# ------ True 48 1 ------
# real action: 41
# False 41
# real action: 46
# False 46
# real action: 49
# ------ True 49 2 ------
# real action: 49
# ------ True 49 0 ------
# real action: 12
# False 24
# real action: 48
# ------ True 48 1 ------
# real action: 48
# ------ True 48 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 25
# False 25
# real action: 49
# ------ True 49 1 ------
# real action: 48
# ------ True 48 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 41
# False 41
# real action: 13
# False 24
# real action: 4
# False 24
# real action: 49
# ------ True 49 3 ------
# real action: 24
# False 24
# real action: 48
# ------ True 48 1 ------
# real action: 48
# ------ True 48 0 ------
# real action: 26
# False 26
# real action: 48
# ------ True 48 1 ------
# real action: 49
# ------ True 49 0 ------
# real action: 31
# False 31
# real action: 52
# False 52
# real action: 57
# False 57
# real action: 45
# False 45
# real action: 49
# ------ True 49 4 ------
# real action: 48
# ------ True 48 0 ------
# real action: 58
# False 58
# real action: 49
# ------ True 49 1 ------
# real action: 48
# ------ True 48 0 ------
# real action: 31
# False 31
# real action: 48
# ------ True 48 1 ------
# real action: 65
# False 65
# real action: 49
# ------ True 49 1 ------
# real action: 4
# False 24
# real action: 49
# ------ True 49 1 ------
# real action: 49
# ------ True 49 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 6
# False 24
# real action: 10
# False 24
# real action: 49
# ------ True 49 2 ------
# real action: 48
# ------ True 48 0 ------
# real action: 61
# False 61
# real action: 48
# ------ True 48 1 ------
# real action: 49
# ------ True 49 0 ------
# real action: 62
# False 62
# real action: 49
# ------ True 49 1 ------
# real action: 50
# ------ True 50 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 13
# False 24
# real action: 48
# ------ True 48 1 ------
# real action: 45
# False 45
# real action: 59
# False 59
# real action: 2
# False 24
# real action: 19
# False 24
# real action: 48
# ------ True 48 4 ------
# real action: 48
# ------ True 48 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 34
# False 34
# real action: 1
# False 24
# real action: 65
# False 65
# real action: 48
# ------ True 48 3 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 14
# False 24
# real action: 48
# ------ True 48 1 ------
# real action: 48
# ------ True 48 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 30
# False 30
# real action: 47
# False 47
# real action: 13
# False 24
# real action: 49
# ------ True 49 3 ------
# real action: 64
# False 64
# real action: 49
# ------ True 49 1 ------
# real action: 15
# False 24
# real action: 62
# False 62
# real action: 48
# ------ True 48 2 ------
# real action: 50
# ------ True 50 0 ------
# real action: 45
# False 45
# real action: 27
# False 27
# real action: 49
# ------ True 49 2 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 50
# ------ True 50 0 ------
# real action: 56
# False 56
# real action: 8
# False 24
# real action: 48
# ------ True 48 2 ------
# real action: 38
# False 38
# real action: 49
# ------ True 49 1 ------
# real action: 48
# ------ True 48 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 23
# False 24
# real action: 49
# ------ True 49 1 ------
# real action: 68
# False 68
# real action: 45
# False 45
# real action: 49
# ------ True 49 2 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 35
# False 35
# real action: 49
# ------ True 49 1 ------
# real action: 49
# ------ True 49 0 ------
# real action: 12
# False 24
# real action: 65
# False 65
# real action: 48
# ------ True 48 2 ------
# real action: 57
# False 57
# real action: 50
# ------ True 50 1 ------
# real action: 50
# ------ True 50 0 ------
# real action: 53
# False 53
# real action: 40
# False 40
# real action: 48
# ------ True 48 2 ------
# real action: 48
# ------ True 48 0 ------
# -------------------------------------
# | approxkl           | 0.0040200436 |
# | clipfrac           | 0.013671875  |
# | explained_variance | 0            |
# | fps                | 0            |
# | n_updates          | 5            |
# | policy_entropy     | 2.836185     |
# | policy_loss        | -0.058019646 |
# | serial_timesteps   | 640          |
# | time_elapsed       | 1.38e+03     |
# | total_timesteps    | 3328         |
# | value_loss         | 29.30121     |
# -------------------------------------
# real action: 48
# ------ True 48 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 19
# False 24
# real action: 33
# False 33
# real action: 49
# ------ True 49 2 ------
# real action: 49
# ------ True 49 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 52
# False 52
# real action: 49
# ------ True 49 1 ------
# real action: 49
# ------ True 49 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 50
# ------ True 50 0 ------
# real action: 58
# False 58
# real action: 48
# ------ True 48 1 ------
# real action: 25
# False 25
# real action: 48
# ------ True 48 1 ------
# real action: 49
# ------ True 49 0 ------
# real action: 61
# False 61
# real action: 48
# ------ True 48 1 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 32
# False 32
# real action: 27
# False 27
# real action: 49
# ------ True 49 2 ------
# real action: 49
# ------ True 49 0 ------
# real action: 30
# False 30
# real action: 48
# ------ True 48 1 ------
# real action: 49
# ------ True 49 0 ------
# real action: 19
# False 24
# real action: 48
# ------ True 48 1 ------
# real action: 48
# ------ True 48 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 25
# False 25
# real action: 41
# False 41
# real action: 47
# False 47
# real action: 7
# False 24
# real action: 48
# ------ True 48 4 ------
# real action: 48
# ------ True 48 0 ------
# real action: 55
# False 55
# real action: 42
# False 42
# real action: 48
# ------ True 48 2 ------
# real action: 53
# False 53
# real action: 49
# ------ True 49 1 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 21
# False 24
# real action: 49
# ------ True 49 1 ------
# real action: 49
# ------ True 49 0 ------
# real action: 6
# False 24
# real action: 60
# False 60
# real action: 49
# ------ True 49 2 ------
# real action: 48
# ------ True 48 0 ------
# real action: 59
# False 59
# real action: 24
# False 24
# real action: 49
# ------ True 49 2 ------
# real action: 48
# ------ True 48 0 ------
# real action: 25
# False 25
# real action: 48
# ------ True 48 1 ------
# real action: 49
# ------ True 49 0 ------
# real action: 51
# False 51
# real action: 48
# ------ True 48 1 ------
# real action: 57
# False 57
# real action: 54
# False 54
# real action: 49
# ------ True 49 2 ------
# real action: 17
# False 24
# real action: 49
# ------ True 49 1 ------
# real action: 48
# ------ True 48 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 67
# False 67
# real action: 48
# ------ True 48 1 ------
# real action: 49
# ------ True 49 0 ------
# real action: 18
# False 24
# real action: 66
# False 66
# real action: 49
# ------ True 49 2 ------
# real action: 58
# False 58
# real action: 49
# ------ True 49 1 ------
# real action: 48
# ------ True 48 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 50
# ------ True 50 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 19
# False 24
# real action: 49
# ------ True 49 1 ------
# real action: 48
# ------ True 48 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 64
# False 64
# real action: 49
# ------ True 49 1 ------
# real action: 52
# False 52
# real action: 49
# ------ True 49 1 ------
# real action: 49
# ------ True 49 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 19
# False 24
# real action: 65
# False 65
# real action: 32
# False 32
# real action: 49
# ------ True 49 3 ------
# real action: 32
# False 32
# real action: 48
# ------ True 48 1 ------
# real action: 48
# ------ True 48 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 53
# False 53
# real action: 49
# ------ True 49 1 ------
# real action: 49
# ------ True 49 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 58
# False 58
# real action: 33
# False 33
# real action: 49
# ------ True 49 2 ------
# real action: 48
# ------ True 48 0 ------
# -------------------------------------
# | approxkl           | 0.0044165007 |
# | clipfrac           | 0.01953125   |
# | explained_variance | -1.19e-07    |
# | fps                | 0            |
# | n_updates          | 6            |
# | policy_entropy     | 2.4774013    |
# | policy_loss        | -0.06831329  |
# | serial_timesteps   | 768          |
# | time_elapsed       | 1.76e+03     |
# | total_timesteps    | 3456         |
# | value_loss         | 28.764446    |
# -------------------------------------
# real action: 49
# ------ True 49 0 ------
# real action: 54
# False 54
# real action: 49
# ------ True 49 1 ------
# real action: 49
# ------ True 49 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 17
# False 24
# real action: 48
# ------ True 48 1 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 33
# False 33
# real action: 49
# ------ True 49 1 ------
# real action: 48
# ------ True 48 0 ------
# real action: 27
# False 27
# real action: 49
# ------ True 49 1 ------
# real action: 49
# ------ True 49 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 19
# False 24
# real action: 48
# ------ True 48 1 ------
# real action: 48
# ------ True 48 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 40
# False 40
# real action: 48
# ------ True 48 1 ------
# real action: 10
# False 24
# real action: 59
# False 59
# real action: 4
# False 24
# real action: 41
# False 41
# real action: 48
# ------ True 48 4 ------
# real action: 6
# False 24
# real action: 48
# ------ True 48 1 ------
# real action: 32
# False 32
# real action: 49
# ------ True 49 1 ------
# real action: 49
# ------ True 49 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 47
# False 47
# real action: 56
# False 56
# real action: 49
# ------ True 49 2 ------
# real action: 48
# ------ True 48 0 ------
# real action: 33
# False 33
# real action: 28
# False 28
# real action: 49
# ------ True 49 2 ------
# real action: 48
# ------ True 48 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 16
# False 24
# real action: 48
# ------ True 48 1 ------
# real action: 48
# ------ True 48 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 10
# False 24
# real action: 53
# False 53
# real action: 49
# ------ True 49 2 ------
# real action: 53
# False 53
# real action: 48
# ------ True 48 1 ------
# real action: 49
# ------ True 49 0 ------
# real action: 58
# False 58
# real action: 46
# False 46
# real action: 48
# ------ True 48 2 ------
# real action: 40
# False 40
# real action: 48
# ------ True 48 1 ------
# real action: 48
# ------ True 48 0 ------
# real action: 34
# False 34
# real action: 49
# ------ True 49 1 ------
# real action: 41
# False 41
# real action: 58
# False 58
# real action: 49
# ------ True 49 2 ------
# real action: 49
# ------ True 49 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 65
# False 65
# real action: 10
# False 24
# real action: 48
# ------ True 48 2 ------
# real action: 34
# False 34
# real action: 48
# ------ True 48 1 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 31
# False 31
# real action: 49
# ------ True 49 1 ------
# real action: 48
# ------ True 48 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 11
# False 24
# real action: 48
# ------ True 48 1 ------
# real action: 49
# ------ True 49 0 ------
# real action: 22
# False 24
# real action: 22
# False 24
# real action: 49
# ------ True 49 2 ------
# real action: 34
# False 34
# real action: 16
# False 24
# real action: 48
# ------ True 48 2 ------
# real action: 49
# ------ True 49 0 ------
# real action: 28
# False 28
# real action: 48
# ------ True 48 1 ------
# real action: 49
# ------ True 49 0 ------
# real action: 24
# False 24
# real action: 48
# ------ True 48 1 ------
# real action: 49
# ------ True 49 0 ------
# real action: 49
# ------ True 49 0 ------
# real action: 48
# ------ True 48 0 ------
# real action: 19
# False 24
# real action: 49
# ------ True 49 1 ------
# real action: 16
# False 24
# real action: 48
# ------ True 48 1 ------
# real action: 49
# ------ True 49 0 ------
# -------------------------------------
# | approxkl           | 0.0025439204 |
# | clipfrac           | 0.021484375  |
# | explained_variance | -1.19e-07    |
# | fps                | 0            |
# | n_updates          | 7            |
# | policy_entropy     | 2.2528756    |
# | policy_loss        | -0.04767617  |
# | serial_timesteps   | 896          |
# | time_elapsed       | 2.14e+03     |
# | total_timesteps    | 3584         |
# | value_loss         | 27.141024    |
# -------------------------------------

# %%
#model.save("model_reward_type2")

# %%
# Enjoy trained agent
obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
# Out:
# real action: 49
# ------ True 49 0 ------
# real action: 67
# not detected
# False 67
# real action: 49
# ------ True 49 2 ------
# real action: 49
# ------ True 49 3 ------
# real action: 49
# ------ True 49 4 ------
# real action: 50
# not detected
# False 50
# real action: 49
# ------ True 49 6 ------
# real action: 64
# not detected
# False 64
# real action: 66
# not detected
# False 66
# real action: 49
# ------ True 49 9 ------
# real action: 49
# ------ True 49 10 ------
# real action: 14
# not detected
# False 24
# real action: 34
# not detected
# False 34
# real action: 49
# ------ True 49 13 ------
# real action: 49
# ------ True 49 14 ------
# real action: 7
# not detected
# False 24
# real action: 49
# ------ True 49 16 ------
# real action: 48
# ------ True 48 17 ------
# real action: 49
# ------ True 49 18 ------
# real action: 49
# ------ True 49 19 ------
# real action: 27
# not detected
# False 27
# real action: 32
# not detected
# False 32
# real action: 44
# not detected
# False 44
# real action: 49
# ------ True 49 23 ------
# real action: 48
# ------ True 48 24 ------
# real action: 48
# ------ True 48 25 ------
# real action: 49
# ------ True 49 26 ------
# real action: 48
# ------ True 48 27 ------
# real action: 49
# ------ True 49 28 ------
# real action: 48
# ------ True 48 29 ------
# real action: 48
# ------ True 48 30 ------
# real action: 48
# ------ True 48 31 ------
# real action: 26
# not detected
# False 26
# real action: 48
# ------ True 48 33 ------
# real action: 24
# not detected
# False 24
# real action: 48
# ------ True 48 35 ------
# real action: 49
# ------ True 49 36 ------
# real action: 49
# ------ True 49 37 ------
# real action: 49
# ------ True 49 38 ------
# real action: 35
# not detected
# False 35
# real action: 48
# ------ True 48 40 ------
# real action: 24
# not detected
# False 24
# real action: 48
# ------ True 48 42 ------
# real action: 48
# ------ True 48 43 ------
# real action: 17
# not detected
# False 24
# real action: 57
# not detected
# False 57
# real action: 48
# ------ True 48 46 ------
# real action: 14
# not detected
# False 24
# real action: 68
# not detected
# False 68
# real action: 49
# ------ True 49 49 ------
# real action: 48
# ------ True 48 50 ------
# real action: 26
# not detected
# False 26
# real action: 49
# not detected
# False 49
# real action: 48
# ------ True 48 53 ------
# real action: 48
# ------ True 48 54 ------
# real action: 48
# ------ True 48 55 ------
# real action: 49
# ------ True 49 56 ------
# real action: 34
# not detected
# False 34
# real action: 49
# ------ True 49 58 ------
# real action: 29
# not detected
# False 29
# real action: 64
# not detected
# False 64
# real action: 49
# ------ True 49 61 ------
# real action: 49
# ------ True 49 62 ------
# real action: 49
# ------ True 49 63 ------
# real action: 62
# not detected
# False 62
# real action: 49
# ------ True 49 65 ------
# real action: 49
# ------ True 49 66 ------
# real action: 49
# ------ True 49 67 ------
# real action: 49
# ------ True 49 68 ------
# real action: 25
# not detected
# False 25
# real action: 60
# not detected
# False 60
# real action: 44
# not detected
# False 44
# real action: 49
# ------ True 49 72 ------
# real action: 48
# ------ True 48 73 ------
# real action: 50
# not detected
# False 50
# real action: 48
# ------ True 48 75 ------
# real action: 49
# ------ True 49 76 ------
# real action: 63
# not detected
# False 63
# real action: 48
# ------ True 48 78 ------
# real action: 49
# ------ True 49 79 ------
# real action: 48
# ------ True 48 80 ------
# real action: 48
# ------ True 48 81 ------
# real action: 49
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-148b02f48c33> in <module>
#       3 while True:
#       4     action, _states = model.predict(obs)
# ----> 5     obs, rewards, dones, info = env.step(action)
#
# <ipython-input-21-d8acdcd89329> in step(self, action)
#     157             action = 24
#     158
# --> 159         self.lens_movement(action)
#     160
#     161
#
# <ipython-input-21-d8acdcd89329> in lens_movement(self, action)
#     133         x = c_double(action)
#     134         self.lib.Casp_SetFocusVoltage(x)
# --> 135         time.sleep(2)
#     136
#     137     def grab_image(self):
#
# KeyboardInterrupt:

# %%
#model.learn(total_timesteps=1000, tb_log_name="p_")
# Out:
# WARNING:tensorflow:From C:\Users\CIG\Anaconda3\envs\corning\lib\site-packages\stable_baselines\common\base_class.py:1169: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
# From C:\Users\CIG\Anaconda3\envs\corning\lib\site-packages\stable_baselines\common\base_class.py:1169: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
# real action: 67
# False 67
# real action: 7
# False 24
# real action: 0
# False 24
# real action: 0
# False 24
# real action: 67
# False 67
# real action: 60
# False 60
# real action: 54
# False 54
# real action: 58
# False 58
# real action: 56
# False 56
# real action: 62
# False 62
# real action: 41
# False 41
# real action: 22
# False 24
# real action: 4
# False 24
# real action: 20
# False 24
# real action: 6
# False 24
# real action: 8
# False 24
# real action: 12
# False 24
# real action: 54
# False 54
# real action: 60
# False 60
# real action: 40
# False 40
# real action: 27
# False 27
# real action: 11
# False 24
# real action: 31
# False 31
# real action: 2
# False 24
# real action: 57
# False 57
# real action: 45
# False 45
# real action: 21
# False 24
# real action: 11
# False 24
# real action: 8
# False 24
# real action: 18
# False 24
# real action: 36
# False 36
# real action: 64
# False 64
# real action: 7
# False 24
# real action: 62
# False 62
# real action: 43
# False 43
# real action: 3
# False 24
# real action: 54
# False 54
# real action: 23
# False 24
# real action: 56
# False 56
# real action: 10
# False 24
# real action: 61
# False 61
# real action: 24
# False 24
# real action: 16
# False 24
# real action: 3
# False 24
# real action: 48
# True 48 44
# real action: 61
# False 61
# real action: 46
# False 46
# real action: 14
# False 24
# real action: 61
# False 61
# real action: 53
# False 53
# real action: 22
# False 24
# real action: 68
# False 68
# real action: 17
# False 24
# real action: 59
# False 59
# real action: 61
# False 61
# real action: 41
# False 41
# real action: 64
# False 64
# real action: 26
# False 26
# real action: 59
# False 59
# real action: 6
# False 24
# real action: 45
# False 45
# real action: 24
# False 24
# real action: 35
# False 35
# real action: 9
# False 24
# real action: 66
# False 66
# real action: 50
# False 50
# real action: 16
# False 24
# real action: 26
# False 26
# real action: 7
# False 24
# real action: 34
# False 34
# real action: 15
# False 24
# real action: 19
# False 24
# real action: 44
# False 44
# real action: 60
# False 60
# real action: 32
# False 32
# real action: 61
# False 61
# real action: 19
# False 24
# real action: 2
# False 24
# real action: 62
# False 62
# real action: 54
# False 54
# real action: 5
# False 24
# real action: 53
# False 53
# real action: 37
# False 37
# real action: 60
# False 60
# real action: 51
# False 51
# real action: 66
# False 66
# real action: 34
# False 34
# real action: 20
# False 24
# real action: 41
# False 41
# real action: 42
# False 42
# real action: 21
# False 24
# real action: 51
# False 51
# real action: 0
# False 24
# real action: 31
# False 31
# real action: 39
# False 39
# real action: 43
# False 43
# real action: 41
# False 41
# real action: 57
# False 57
# real action: 51
# False 51
# real action: 62
# False 62
# real action: 63
# False 63
# real action: 15
# False 24
# real action: 49
# True 49 57
# real action: 67
# False 67
# real action: 5
# False 24
# real action: 8
# False 24
# real action: 64
# False 64
# real action: 67
# False 67
# real action: 11
# False 24
# real action: 27
# False 27
# real action: 22
# False 24
# real action: 44
# False 44
# real action: 11
# False 24
# real action: 19
# False 24
# real action: 17
# False 24
# real action: 11
# False 24
# real action: 3
# False 24
# real action: 41
# False 41
# real action: 5
# False 24
# real action: 65
# False 65
# real action: 39
# False 39
# real action: 7
# False 24
# real action: 64
# False 64
# real action: 63
# False 63
# real action: 21
# False 24
# real action: 57
# False 57
# real action: 46
# False 46
# real action: 66
# False 66
# WARNING:tensorflow:From C:\Users\CIG\Anaconda3\envs\corning\lib\site-packages\stable_baselines\common\tf_util.py:502: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
# From C:\Users\CIG\Anaconda3\envs\corning\lib\site-packages\stable_baselines\common\tf_util.py:502: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
# -----------------------------------
# | approxkl           | 116.20806  |
# | clipfrac           | 0.85546875 |
# | explained_variance | 0.00536    |
# | fps                | 0          |
# | n_updates          | 1          |
# | policy_entropy     | 2.2791548  |
# | policy_loss        | 0.47831768 |
# | serial_timesteps   | 128        |
# | time_elapsed       | 0          |
# | total_timesteps    | 128        |
# | value_loss         | 70.17524   |
# -----------------------------------
# real action: 36
# False 36
# real action: 63
# False 63
# real action: 39
# False 39
# real action: 36
# False 36
# real action: 36
# False 36
# real action: 36
# False 36
# real action: 63
# False 63
# real action: 63
# False 63
# real action: 39
# False 39
# real action: 63
# False 63
# real action: 63
# False 63
# real action: 36
# False 36
# real action: 39
# False 39
# real action: 36
# False 36
# real action: 36
# False 36
# real action: 63
# False 63
# real action: 39
# False 39
# real action: 36
# False 36
# real action: 39
# False 39
# real action: 36
# False 36
# real action: 63
# False 63
# real action: 39
# False 39
# real action: 39
# False 39
# real action: 48
# True 48 48
# real action: 36
# False 36
# real action: 39
# False 39
# real action: 36
# False 36
# real action: 39
# False 39
# real action: 39
# False 39
# real action: 39
# False 39
# real action: 39
# False 39
# real action: 63
# False 63
# real action: 39
# False 39
# real action: 36
# False 36
# real action: 36
# False 36
# real action: 39
# False 39
# real action: 36
# False 36
# real action: 39
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-d66341f457ee> in <module>
# ----> 1 model.learn(total_timesteps=1000, tb_log_name="p_")
#
# ~\Anaconda3\envs\corning\lib\site-packages\stable_baselines\ppo2\ppo2.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps)
#     334                 callback.on_rollout_start()
#     335                 # true_reward is the reward without discount
# --> 336                 rollout = self.runner.run(callback)
#     337                 # Unpack
#     338                 obs, returns, masks, actions, values, neglogpacs, states, ep_infos, true_reward = rollout
#
# ~\Anaconda3\envs\corning\lib\site-packages\stable_baselines\common\runners.py in run(self, callback)
#      46         self.callback = callback
#      47         self.continue_training = True
# ---> 48         return self._run()
#      49
#      50     @abstractmethod
#
# ~\Anaconda3\envs\corning\lib\site-packages\stable_baselines\ppo2\ppo2.py in _run(self)
#     480             if isinstance(self.env.action_space, gym.spaces.Box):
#     481                 clipped_actions = np.clip(actions, self.env.action_space.low, self.env.action_space.high)
# --> 482             self.obs[:], rewards, self.dones, infos = self.env.step(clipped_actions)
#     483
#     484             self.model.num_timesteps += self.n_envs
#
# ~\Anaconda3\envs\corning\lib\site-packages\stable_baselines\common\vec_env\base_vec_env.py in step(self, actions)
#     148         """
#     149         self.step_async(actions)
# --> 150         return self.step_wait()
#     151
#     152     def get_images(self) -> Sequence[np.ndarray]:
#
# ~\Anaconda3\envs\corning\lib\site-packages\stable_baselines\common\vec_env\dummy_vec_env.py in step_wait(self)
#      42         for env_idx in range(self.num_envs):
#      43             obs, self.buf_rews[env_idx], self.buf_dones[env_idx], self.buf_infos[env_idx] =\
# ---> 44                 self.envs[env_idx].step(self.actions[env_idx])
#      45             if self.buf_dones[env_idx]:
#      46                 # save final observation where user can get it, then reset
#
# <ipython-input-2-4c3e120372b6> in step(self, action)
#     157             action = 24
#     158
# --> 159         self.lens_movement(action)
#     160
#     161
#
# <ipython-input-2-4c3e120372b6> in lens_movement(self, action)
#     133         x = c_double(action)
#     134         self.lib.Casp_SetFocusVoltage(x)
# --> 135         time.sleep(2)
#     136
#     137     def grab_image(self):
#
# KeyboardInterrupt:

# %%
#tensorboard --logdir=C:\\Users\\CIG\\Documents\\MATLAB

# %%
camera.Close()
